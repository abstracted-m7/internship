# %% [markdown]
# #Questions of the day-
# ##--------------------------------------
# #Question 1: A 25-year-old passenger in 2nd class has a predicted probability of survival P=0.62. Classify the outcome (Survived/Did Not Survive).
# Explain why the threshold of 0.5 matters.
# ##--------------------------------------
# #Question 2: A 45-year-old passanger in 3rd class has P=0.38.
# i. What does this probability mean/
# ii. How would the model's decision change if the threshold were 0.4 instead of 0.5?
# ##--------------------------------------
# #Question 3: A 10-year-old passanger in 1st class has P = 0.85.
# i. Interpret the probability.
# ii. Discuss how age and class might influence the coefficents bita1 and bita3.
# ##--------------------------------------
# #bonus Challenge:
# If gender is added as a variable and the coefficent for "female" is positive, what does that tell us about survival likelihood?
